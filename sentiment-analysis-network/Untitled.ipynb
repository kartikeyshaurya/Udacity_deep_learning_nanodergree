# %%
word2index = {'': 0,
 'literature': 1,
 'paranoia': 2,
 'noughts': 3,
 'leverage': 4,
 'highpoint': 5,
 'stanford': 6,
 'sleezebag': 7,
 'peers': 8,
 'toasters': 9,
 'prised': 10,
 'californian': 11,
 'progrmmer': 12,
 'gilligan': 13,
 'bundled': 14,
 'shortfalls': 15,
 'costa': 16,
 'playwright': 17,
 'ultranationalist': 18,
 'huntz': 19,
 'kashakim': 20,
 'inroads': 21,
 'narrator': 22,
 'councilor': 23,
 'candidates': 24,
 'fabinyi': 25,
 'hiarity': 26,
 'sympathise': 27,
 'gielguld': 28,
 'malebranche': 29,
 'granted': 30,
 'earp': 31,
 'roladex': 32,
 'wedgie': 33,
 'albertine': 34,
 'mera': 35,
 'aroma': 36,
 'screwer': 37,
 'madres': 38,
 'beaux': 39,
 'brosnan': 40,
 'pyrokineticists': 41,
 'blazes': 42,
 'muska': 43,
 'bhandarkar': 44,
 'tactless': 45,
 'tuco': 46,
 'reshaping': 47,
 'thurmanshe': 48,
 'octavian': 49,
 'scaredy': 50,
 'parcel': 51,
 'pensylvannia': 52,
 'disconnect': 53,
 'poltergeist': 54,
 'kuttram': 55,
 'bibles': 56,
 'comedygenre': 57,
 'leeson': 58,
 'kurta': 59,
 'allergy': 60,
 'blech': 61,
 'carrel': 62,
 'creepily': 63,
 'liye': 64,
 'dussolier': 65,
 'appropriating': 66,
 'genres': 67,
 'gassed': 68,
 'rake': 69,
 'already': 70,
 'miyako': 71,
 'pommel': 72,
 'dino': 73,
 'complaisance': 74,
 'cutbacks': 75,
 'gunpowder': 76,
 'hairy': 77,
 'biographic': 78,
 'josten': 79,
 'compels': 80,
 'casnoff': 81,
 'oana': 82,
 'intrinsic': 83,
 'matte': 84,
 'menalaus': 85,
 'libra': 86,
 'appoints': 87,
 'squatters': 88,
 'ruta': 89,
 'gaynigger': 90,
 'hipster': 91,
 'verit': 92,
 'imperfectionist': 93,
 'broader': 94,
 'visualise': 95,
 'gustav': 96,
 'crucification': 97,
 'demeanour': 98,
 'darlanne': 99,
 'cang': 100,
 'beth': 101,
 'holm': 102,
 'egocentric': 103,
 'candice': 104,
 'apogee': 105,
 'betts': 106,
 'inexhaustible': 107,
 'mohandas': 108,
 'divulges': 109,
 'housewifes': 110,
 'purchasers': 111,
 'commandeered': 112,
 'mutiny': 113,
 'construction': 114,
 'bratwurst': 115,
 'bannen': 116,
 'watershed': 117,
 'deformities': 118,
 'stasi': 119,
 'alarmists': 120,
 'rapacious': 121,
 'tenth': 122,
 'cartoons': 123,
 'idiosyncracies': 124,
 'teeters': 125,
 'cal': 126,
 'denny': 127,
 'harassing': 128,
 'attributions': 129,
 'michalka': 130,
 'slogging': 131,
 'dwindled': 132,
 'tanaka': 133,
 'marca': 134,
 'xvii': 135,
 'chasing': 136,
 'overdue': 137,
 'jameson': 138,
 'guile': 139,
 'yuma': 140,
 'hitherto': 141,
 'corsets': 142,
 'sobre': 143,
 'button': 144,
 'uncensored': 145,
 'inciteful': 146,
 'erb': 147,
 'nisha': 148,
 'adelle': 149,
 'breakthrough': 150,
 'nemsis': 151,
 'leese': 152,
 'loughed': 153,
 'omirus': 154,
 'doorknobs': 155,
 'mutation': 156,
 'desis': 157,
 'recruitment': 158,
 'quickliy': 159,
 'apres': 160,
 'choreographer': 161,
 'artistes': 162,
 'safeauto': 163,
 'funk': 164,
 'duran': 165,
 'miltonesque': 166,
 'edwige': 167,
 'warlocks': 168,
 'vigour': 169,
 'gibbons': 170,
 'mucky': 171,
 'ferdos': 172,
 'nobu': 173,
 'naruto': 174,
 'pummeled': 175,
 'azar': 176,
 'burgi': 177,
 'schulberg': 178,
 'simmer': 179,
 'chairman': 180,
 'raghavan': 181,
 'stefanovic': 182,
 'coppers': 183,
 'comanche': 184,
 'coroner': 185,
 'bagdad': 186,
 'seventy': 187,
 'mosquitos': 188,
 'tokenistic': 189,
 'brune': 190,
 'gnawed': 191,
 'senorita': 192,
 'escpecially': 193,
 'aldar': 194,
 'relaxed': 195,
 'omnipotent': 196,
 'nonaquatic': 197,
 'villified': 198,
 'mercado': 199,
 'disbeliever': 200,
 'christs': 201,
 'beserk': 202,
 'procurer': 203,
 'squelching': 204,
 'greeley': 205,
 'markey': 206,
 'realtor': 207,
 'watertank': 208,
 'corson': 209,
 'lard': 210,
 'fikret': 211,
 'revealled': 212,
 'goggle': 213,
 'cassidy': 214,
 'wounded': 215,
 'franky': 216,
 'orlandi': 217,
 'missable': 218,
 'hasselhof': 219,
 'strikes': 220,
 'joking': 221,
'scaredy': 250,
 'parcel': 251,
 'pensylvannia': 252,
 'disconnect': 253,
 'poltergeist': 254,
 'kuttram': 255,
 'bibles': 256,
 'comedygenre': 257,
 'leeson': 258,
 'kurta': 259,
 'allergy': 260,
 'blech': 261,
 'carrel': 262,
 'creepily': 263,}

# %% [markdown]
# #TODO: Complete the implementation of update_input_layer. It should count how many times each word is used in the given review, and then store those counts at the appropriate indices inside layer_0.
#
# def update_input_layer(review):
#     """ Modify the global layer_0 to represent the vector form of review.
#     The element at a given index of layer_0 should represent
#     how many times the given word occurs in the review.
#     Args:
#         review(string) - the string of the review
#     Returns:
#         None
#     """
#     global layer_0
#     # clear out previous state by resetting the layer to be all 0s
#     layer_0 *= 0
#
#     # TODO: count how many times each word is used in the given review and store the results in layer_0

# %%
count= 0 
dic = { 'literature': 1,
 'paranoia': 2,
 'noughts': 3,
 'leverage': 4,
 'highpoint': 5,
       'literature': 11,
 'paranoia': 12,
 'noughts': 13,
 'leverage': 14,
 'highpoint': 15,}
for i in dic:
    print(i)
        #compare the words 
        #count them 
        #put them in the dict
# Out:
# literature
# paranoia
# noughts
# leverage
# highpoint

# %%
update_input_layer(word2index)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-14-990f8eeb4ef0> in <module>
# ----> 1 update_input_layer(word2index)
#
# <ipython-input-13-21173407dfa4> in update_input_layer(review)
#       4         for j in review:
#       5             if j == words :
# ----> 6                 count =count +1
#       7             j = j+1
#       8         #compare the words
#
# UnboundLocalError: local variable 'count' referenced before assignment

# %%
kar = {"Ary": 12 , "ammy": 13 }

kar.keys()
# Out:
# dict_keys(['Ary', 'ammy'])
